# %%
from __future__ import absolute_import, division, print_function

# %%
import subprocess

# %%
import kimpy

# %%
kimpy.collection.get_number_of_collections()
# Out:
# 4

# %%
for i in range(kimpy.collection.get_number_of_collections()):
    print(kimpy.collection.get_collection(i))
# Out:
# (system, 0)
# (user, 0)
# (environmentVariable, 0)
# (currentWorkingDirectory, 0)

# %%
subprocess.check_output(['kim-api-collections-management', 'list'], universal_newlines=True).split('\n')
# Out:
# ['',
#  '',
#  'Knowledgebase of Interatomic Models (KIM)  ---  Model Collections Listing',
#  '===============================================================================',
#  '',
#  'kim-api : ',
#  '\tkim-api 2.1.3+GNU',
#  '',
#  'kim-api configuration file:',
#  '\t/home/jovyan/.kim-api/config',
#  '',
#  '',
#  'Environment Variables:',
#  '-------------------------------------------------------------------------------',
#  'KIM_API_CMAKE_PREFIX_DIR:',
#  '\t--empty--',
#  '',
#  'KIM_API_CONFIGURATION_FILE:',
#  '\t--empty--',
#  '',
#  'KIM_API_MODEL_DRIVERS_DIR:',
#  '\t--empty--',
#  '',
#  'KIM_API_PORTABLE_MODELS_DIR:',
#  '\t--empty--',
#  '',
#  'KIM_API_SIMULATOR_MODELS_DIR:',
#  '\t--empty--',
#  '',
#  '===============================================================================',
#  '',
#  '',
#  '',
#  'Current Working Directory Collection',
#  '-------------------------------------------------------------------------------',
# ...
